# %% [markdown]
# # News

# %%
from newsapi import NewsApiClient
# from kafka import KafkaProducer
from datetime import datetime
from textblob import TextBlob
import json
import requests

# %%
# API key for News API
news_api_key = "8b331c71e2294e45bfae1d93054177df"

# Initialize News API client
newsapi = NewsApiClient(api_key=news_api_key)

# %%
# Parameters
query = "Nvidia"
start_date = "2025-05-05"
end_date = "2025-05-30"

# %%
# Fetch news articles
news_articles = newsapi.get_everything(
    q=query,
    from_param=start_date,
    to=end_date,
    language="en",
    sort_by="relevancy"
)

# %%
df_news = []

# Process and send articles
for article in news_articles['articles']:
    published_date = datetime.strptime(article['publishedAt'], "%Y-%m-%dT%H:%M:%SZ").strftime('%Y-%m-%d')
    message = {
        "date": published_date,
        "source": article['source']['name'],
        "title": article['title'],
        "description": article['description'] or "No description provided",
        "polarity": TextBlob(article['description'] or "").sentiment.polarity # Polarity ranges from -1 (negative) to 1 (positive)
    }
    df_news.append(message)
    print(f"{message}")
# Out:
# {'date': '2025-05-14', 'source': 'The Verge', 'title': 'Nvidia’s flattery of Trump wins reversal of AI chip limits and a Huawei clampdown', 'description': 'Nvidia’s efforts to suck up to the Trump administration have seemingly paid off, with the US now lifting export limits on US-made AI chips and cracking down on anyone using Huawei’s emerging alternatives. The announcements come as Nvidia CEO Jensen Huang join…', 'polarity': -0.15555555555555559}
# {'date': '2025-05-08', 'source': 'The Verge', 'title': 'Lenovo’s flagship gaming laptop has a 2D / 3D screen and carbon fiber lid', 'description': 'Lenovo is announcing a new 10th-generation Legion 9i gaming laptop coming soon to China and scheduled for the fall in North America. The 18-inch behemoth is packed with top-end specs, including the option for a 4K-capable 2D / 3D screen, Nvidia RTX 5090 GPU, …', 'polarity': 0.13636363636363635}
# {'date': '2025-05-14', 'source': 'The Verge', 'title': 'Switch 2 spec breakdown digs into its processor and GameChat', 'description': 'Nintendo’s Switch 2 specs page is light on details. However, Digital Foundry has shared what it says are “rock solid” specifications for the upcoming console in an article and a video, offering new information about its processor and a testing tool for develo…', 'polarity': 0.1340909090909091}
# {'date': '2025-05-15', 'source': 'Wired', 'title': 'The Middle East Has Entered the AI Group Chat', 'description': 'The UAE and Saudi Arabia are investing billions in US AI infrastructure. The deals could help the US in the AI race against China.', 'polarity': 0.0}
# {'date': '2025-05-29', 'source': 'The Verge', 'title': 'Tested: Nvidia’s GeForce Now just breathed new life into my Steam Deck', 'description': "I don't want gaming to become another streaming subscription service that keeps going up in price. I don't want to put even more power in Nvidia's hands, particularly not right now. But I can't deny that the company's $20-a-month* GeForce Now is a near-perfec…", 'polarity': 0.17857142857142858}
# {'date': '2025-05-30', 'source': 'Business Insider', 'title': "Nvidia's most important number doesn't have a dollar sign in front of it: Token growth", 'description': "Want to know how demand for Nvidia chips is changing? It's all about tokens.", 'polarity': 0.0}
# {'date': '2025-05-21', 'source': 'Business Insider', 'title': "Inside Asia's biggest tech trade show, where Nvidia's 'Jensen' is the hottest name drop", 'description': 'Nvidia dominates the Computex trade show in Taiwan, where CEO Jensen Huang is massively popular.', 'polarity': 0.6}
# {'date': '2025-05-28', 'source': 'Business Insider', 'title': "Nvidia's earnings report means another big test for the chip giant", 'description': 'Nvidia reports earnings today from unfamiliar territory, amid tariff uncertainty and volatility.', 'polarity': 0.0}
# {'date': '2025-05-19', 'source': 'The Verge', 'title': 'LG’s brilliant C4 OLED is more than 50 percent off for Memorial Day', 'description': 'Memorial Day marks the unofficial start of summer, but it’s also one of the best times of the year to snag a seriously good deal on a top-tier TV. Right now, for instance, you can buy LG’s C4 OLED at Amazon, Best Buy, and LG’s online storefront in the 42-inch…', 'polarity': 0.7464285714285714}
# {'date': '2025-05-19', 'source': 'VentureBeat', 'title': 'Nvidia and Microsoft accelerate AI processing on PCs', 'description': 'Nvidia and Microsoft announced work to accelerate the performance of AI processing on Nvidia RTX-based AI PCs. Generative AI is transforming PC software into breakthrough experiences — from digital humans to writing assistants, intelligent agents and creative…', 'polarity': 0.4}
# {'date': '2025-05-06', 'source': 'Business Insider', 'title': "Nvidia CEO says 'San Francisco is back' — and it's thanks to the AI gold rush", 'description': '"Just about everybody evacuated San Francisco," Nvidia CEO Jensen Huang said. "Now it\'s thriving again. It\'s all because of AI."', 'polarity': 0.0}
# {'date': '2025-05-19', 'source': 'Business Insider', 'title': "DeepSeek's R1 was 'genuinely a gift to the world's AI industry,' says Jensen Huang", 'description': 'DeepSeek has made a "real impact" in how people think about inference and reasoning AI, the Nvidia CEO said.', 'polarity': 0.2}
# {'date': '2025-05-19', 'source': 'Yahoo Entertainment', 'title': 'Nvidia, Qualcomm, Netflix: Trending Tickers', 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-17', 'source': 'Business Insider', 'title': 'A guide to the Nvidia products driving the AI boom and beyond — from data center GPUs to automotive and consumer tech', 'description': "Nvidia products have been instrumental to the AI boom. Read about the company's data center GPUs, CUDA software, and ventures in automotive tech.", 'polarity': -0.1}
# {'date': '2025-05-29', 'source': 'Business Insider', 'title': "The 3 biggest takeaways from Nvidia's Q1 earnings call: China, China, China", 'description': "Nvidia CEO Jensen Huang had a lot to say about the China restrictions and praised President Donald Trump during the company's Q1 earnings call.", 'polarity': 0.0}
# {'date': '2025-05-28', 'source': 'Yahoo Entertainment', 'title': 'Nvidia earnings live: Nvidia beats on Q1 revenue, sees $8 billion impact from China export rules', 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-11', 'source': 'Business Insider', 'title': "A guide to Nvidia's competitors: AMD, Qualcomm, Broadcom, startups, and more are vying to compete in the AI chip market", 'description': "Despite Nvidia's AI semiconductor dominance, competitors are innovating to challenge its lead. Read about AMD, Qualcomm, Broadcom, Amazon, and more.", 'polarity': 0.5}
# {'date': '2025-05-23', 'source': 'Yahoo Entertainment', 'title': 'Nvidia to report Q1 earnings as Middle East deals, export control reprieve boost stock', 'description': 'Nvidia will report its fiscal first quarter earnings on Wednesday.', 'polarity': 0.25}
# {'date': '2025-05-14', 'source': 'Yahoo Entertainment', 'title': 'Nvidia, Super Micro Computer, Sony: Trending Tickers', 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-15', 'source': 'Slashdot.org', 'title': 'Microsoft Layoffs Hit Coders Hardest With AI Costs on the Rise', 'description': "An anonymous reader shares a report: Microsoft's recently announced job cuts fell hardest on the people who build the company's products, showing that even software developers are at risk in the age of artificial intelligence. \n\nIn Microsoft's home state of W…", 'polarity': -0.3}
# {'date': '2025-05-09', 'source': 'Slashdot.org', 'title': "Nvidia CEO: 'You Won't Lose Your Job To AI, But To Someone Who Uses It'", 'description': 'Nvidia founder and CEO Jensen Huang has served up another blunt take on the job market as AI permeates society. From a report: "You will not lose your job to AI, but will lose it to someone who uses it," Huang said at the Milken Institute Conference. Added Hu…', 'polarity': 0.0}
# {'date': '2025-05-09', 'source': 'Business Insider', 'title': 'Nvidia-backed Israeli AI startup AI21 is raising a $300 million funding round', 'description': 'AI21, an Israeli startup building its own large language models (LLMs), is raising a $300 million funding round, according to a source.', 'polarity': 0.20476190476190478}
# {'date': '2025-05-10', 'source': 'Business Insider', 'title': "Nvidia vice president says GPUs are the 'currency' of AI researchers", 'description': 'Jonathan Cohen, VP of Applied Research at the company, said sacrifices are made for new priorities, both technical and personal.', 'polarity': 0.04545454545454545}
# {'date': '2025-05-15', 'source': 'Business Insider', 'title': "How tech's biggest powerhouses from Amazon to Nvidia are betting on healthcare AI", 'description': "Artificial intelligence is gaining ground in healthcare, and tech's biggest players are racing to stake their claims.", 'polarity': -0.6}
# {'date': '2025-05-14', 'source': 'Yahoo Entertainment', 'title': "Nvidia and AMD Stocks Rally on Trump's Saudi Arabia Visit", 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-29', 'source': 'Yahoo Entertainment', 'title': 'Ives on Nvidia Earnings, AI, Trade War, China', 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-27', 'source': 'Yahoo Entertainment', 'title': 'Nvidia stock: What export controls mean for the chip giant', 'description': 'Nvidia (NVDA) reports its first quarter results after the market close on Wednesday, May 28. Yahoo Finance Anchor Julie Hyman breaks down what China trade...', 'polarity': 0.04722222222222221}
# {'date': '2025-05-19', 'source': 'Business Insider', 'title': "4 big takeaways from Jensen Huang's homecoming speech in Taiwan", 'description': 'Huang introduced a computer system for AI users. "One thing\'s for sure: Everybody can have one for Christmas," he said.', 'polarity': 0.5}
# {'date': '2025-05-07', 'source': 'The Verge', 'title': 'Here’s Alienware’s fresh take on entry-level gaming laptops', 'description': 'Alienware is introducing a pair of new, more affordable gaming laptops: the Aurora 16 and 16X, starting at $1,149 and $1,949, respectively. Unlike the flagship Area-51 laptops announced back at CES, the Auroras are meant to be a little more versatile, portabl…', 'polarity': 0.13555194805194806}
# {'date': '2025-05-22', 'source': 'The Verge', 'title': 'Xiaomi’s new PU7 spells trouble for Tesla in China', 'description': 'Xiaomi unveiled its hotly anticipated PU7 electric SUV in China today, in the latest potential blow to Tesla’s position in the world’s hottest EV market. The electronics giant says the PU7 will get up to 518 miles of range on certain trims and accelerate from…', 'polarity': 0.19285714285714287}
# {'date': '2025-05-23', 'source': 'The Verge', 'title': 'Xiaomi’s new YU7 spells trouble for Tesla in China', 'description': 'Xiaomi unveiled its hotly anticipated YU7 electric SUV in China today, in the latest potential blow to Tesla’s position in the world’s hottest EV market. The electronics giant says the YU7 will get up to 518 miles of range on certain trims and accelerate from…', 'polarity': 0.19285714285714287}
# {'date': '2025-05-19', 'source': 'Yahoo Entertainment', 'title': 'Nvidia in advanced talks to invest in PsiQuantum, The Information reports', 'description': 'Nvidia and PsiQuantum declined to comment on the report.  Reuters reported in March that PsiQuantum is raising at least $750 million from investors including...', 'polarity': -0.3}
# {'date': '2025-05-28', 'source': 'Yahoo Entertainment', 'title': 'Jim Cramer on NVIDIA Corporation (NVDA): “The Stock’s in No Man’s Land”', 'description': 'We recently published a list of Jim Cramer’s Game Plan: 12 Stocks in Focus. In this article, we are going to take a look at where NVIDIA Corporation...', 'polarity': -0.2}
# {'date': '2025-05-06', 'source': 'Gizmodo.com', 'title': 'A New GTA VI Trailer Is Here, but We Still Don’t Know if the Game Is Coming to Switch 2', 'description': "Grand Theft Auto VI is going to be on PS5 and Xbox on May 26, though Switch 2 wasn't mentioned at all.", 'polarity': 0.5}
# {'date': '2025-05-05', 'source': 'Arxiv.org', 'title': 'Analyzing Modern Nvidia GPU Cores', 'description': 'GPUs are the most popular platform for accelerating HPC workloads, such as artificial intelligence and science simulations. However, most microarchitectural research in academia relies on GPU core pipeline designs based on architectures that are more than 15 …', 'polarity': 0.25}
# {'date': '2025-05-19', 'source': 'Business Insider', 'title': "Nvidia CEO says Chinese AI researchers are 'world class' — and US companies are hiring 'a whole bunch' of them", 'description': 'Jensen Huang said US AI companies are being "sensible" by hiring Chinese researchers.', 'polarity': 0.0}
# {'date': '2025-05-30', 'source': 'Slashdot.org', 'title': 'OpenAI and UAE in Talks For Free ChatGPT Plus For All, Report Says', 'description': "An anonymous reader shares a report: Negotiations are under way between the UAE and OpenAI that may make the company's ChatGPT Plus artificial intelligence chatbot available to all residents free of charge, though a final deal has not been reached. \n\nAn agree…", 'polarity': 0.05000000000000002}
# {'date': '2025-05-15', 'source': 'Business Insider', 'title': "Tencent says it has enough high-end chips to train AI for 'generations' even if the US cuts it off", 'description': 'Tencent\'s president said the company can rely on a "pretty strong stockpile of chips that we acquired previously."', 'polarity': 0.17222222222222225}
# {'date': '2025-05-13', 'source': 'Yahoo Entertainment', 'title': "US–China deal is a 'dream scenario' for Apple and Nvidia", 'description': 'The Nasdaq 100 (^NDX) is gaining, erasing "Liberation Day" losses following the US and China\'s agreement to a temporary tariff cut. Wedbush Securities...', 'polarity': 0.0}
# {'date': '2025-05-09', 'source': 'Yahoo Entertainment', 'title': 'Jim Cramer on NVIDIA (NVDA): Bears ‘Getting Gored By The Bulls’', 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-19', 'source': 'Yahoo Entertainment', 'title': 'Nvidia in advanced talks to invest in PsiQuantum, The Information reports', 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-16', 'source': 'Yahoo Entertainment', 'title': 'Veteran fund manager unveils bold Nvidia stock price target after rally', 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-15', 'source': 'Business Insider', 'title': "Watch out, Apple. ChatGPT and Chipotle have joined the list of the world's most valuable brands.", 'description': 'Topping the list for the fourth year in a row is Apple, according to Kantar BrandZ. ChatGPT and Chipotle also made the list for the first time.', 'polarity': 0.125}
# {'date': '2025-05-19', 'source': 'Gizmodo.com', 'title': 'Nvidia Swears You’ll Be Able to Buy an RTX 5060 at $300, but Good Luck Finding One', 'description': 'We’ll have to see it to believe it as the Nvidia RTX 5060 GPU launches today without pre-release drivers.', 'polarity': 0.0}
# {'date': '2025-05-20', 'source': 'Dshr.org', 'title': "The Dawn of Nvidia's Technology", 'description': 'Because Nvidia  became one of the most valuable companies in the world, there are now two books explaining its rise and extolling the geniu...', 'polarity': 0.5}
# {'date': '2025-05-16', 'source': 'Slashdot.org', 'title': 'US, UAE Unveil Plan For New 5GW AI Campus In Abu Dhabi', 'description': "An anonymous reader quotes a report from Patently Apple: It's being reported in the Gulf region that a new 5GW UAE-US AI Campus in Abu Dhabi was unveiled on Thursday at Qasr Al Watan in the presence of President His Highness Sheikh Mohamed bin Zayed Al Nahyan…", 'polarity': 0.13636363636363635}
# {'date': '2025-05-14', 'source': 'Business Insider', 'title': "Trump, Elon Musk, and top CEOs' lavish visit to Saudi Arabia in pictures", 'description': 'President Trump met with Saudi Crown Prince Mohammed bin Salman and attended a US-Saudi investment forum along with Elon Musk and other top CEOs.', 'polarity': 0.1875}
# {'date': '2025-05-13', 'source': 'Polygon', 'title': 'Stellar Blade coming to PC in June, with a ton of new outfits, of course', 'description': 'Stellar Blade is set to launch on Windows PC on June 11, a leaked trailer for the game revealed Monday. With it comes a bevy of PC-specific features and —\xa0you guessed it\xa0— new costumes for Eve. Included in the PC version of Stellar Blade will be AI upscaling …', 'polarity': 0.05909090909090908}
# {'date': '2025-05-07', 'source': 'Business Insider', 'title': "Jensen Huang says he uses AI as a tutor 'every day'", 'description': 'Jensen Huang said at the 28th annual Milken Institute Global Conference that AI is the "greatest opportunity for us to close the technology divide."', 'polarity': 0.5}
# {'date': '2025-05-19', 'source': 'Harvard Business Review', 'title': 'How Arizona Is Powering the Growth of AI - SPONSOR CONTENT FROM ARIZONA COMMERCE AUTHORITY', 'description': 'Sponsor content from Arizona Commerce Authority.', 'polarity': 0.0}
# {'date': '2025-05-06', 'source': 'Tlapl.us', 'title': 'GenAI-Accelerated TLA+ Challenge', 'description': 'The TLA+ Foundation, in collaboration with NVIDIA, is pleased to announce the GenAI-accelerated TLA+ challenge—an open call for submissions that explore the intersection of TLA+ and generative AI. This initiative aims to foster practical and innovative toolin…', 'polarity': 0.3333333333333333}
# {'date': '2025-05-29', 'source': 'The Verge', 'title': 'AI could consume more power than Bitcoin by the end of 2025', 'description': 'AI could soon surpass Bitcoin mining in energy consumption, according to a new analysis that concludes artificial intelligence could use close to half of all the electricity consumed by data centers globally by the end of 2025. The estimates come from Alex de…', 'polarity': -0.15757575757575756}
# {'date': '2025-05-18', 'source': 'BBC News', 'title': "The secretive US factory that lays bare the contradiction in Trump's America First plan", 'description': 'An exclusive look inside the closely guarded factory Trump wants to become a foundation stone for his American golden age. But the company story exemplifies the success of modern globalisation', 'polarity': 0.23333333333333336}
# {'date': '2025-05-23', 'source': 'Yahoo Entertainment', 'title': 'Nvidia earnings, Fed Chair Powell, April PCE: What to Watch', 'description': 'Market Domination Overtime anchors Julie Hyman and Josh Lipton preview the biggest news stories and market headlines expected out next week, including...', 'polarity': -0.05}
# {'date': '2025-05-06', 'source': 'Yahoo Entertainment', 'title': 'Why This Nvidia-Backed Robotaxi Stock Is Skyrocketing Today', 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-23', 'source': 'Yahoo Entertainment', 'title': "Analysis: Amid 'Jensanity', Nvidia signals plans to keep AI crown", 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-08', 'source': 'Gizmodo.com', 'title': 'The $170 Backbone Pro Mobile Controller Falls Just Short of Premium', 'description': "The Backbone Pro wants to be your controller for both mobile and PC, but it's too expensive for what it does.", 'polarity': -0.15}
# {'date': '2025-05-08', 'source': 'Gizmodo.com', 'title': 'I Desperately Hope This Lenovo Gaming Laptop Can Make 3D Screens Mainstream', 'description': 'Glasses-free 3D gaming refuses to die.', 'polarity': 0.0}
# {'date': '2025-05-21', 'source': 'Gizmodo.com', 'title': 'Didn’t Preorder a Switch 2? You May Have Luck Getting One After Launch', 'description': "Retailers like Best Buy and GameStop promise they'll have Nintendo Switch 2 in-store stock.", 'polarity': 1.0}
# {'date': '2025-05-13', 'source': 'Gizmodo.com', 'title': 'Elon Musk Brings Starlink to Saudi Arabia as U.S. Oligarchs Join Trump in Middle East', 'description': 'Trump bragged about the multi-billion dollar deals between Saudi Arabia and Big Tech.', 'polarity': 0.0}
# {'date': '2025-05-22', 'source': '9to5Mac', 'title': 'Kraken to allow trading of tokenized versions of Apple and other popular stocks', 'description': 'If you love Apple and you love crypto, good news: cryptocurrency exchange Kraken is preparing to let users trade tokenized versions of popular stocks like Apple, Tesla, and Nvidia. Except if you’re in the U.S., that is.\n\n\n\n more…', 'polarity': 0.575}
# {'date': '2025-05-21', 'source': 'Gizmodo.com', 'title': 'AMD’s Radeon RX 9060 XT Could Do Budget GPUs Better Than Nvidia', 'description': "We’ll need to see if a 9060 can beat the RTX 5060, but what's more important is if it manages to maintain its price after launch.", 'polarity': 0.45}
# {'date': '2025-05-27', 'source': 'Yahoo Entertainment', 'title': 'Nvidia will release cheaper Blackwell AI chips in China to avoid U.S. restrictions, report says', 'description': 'Nvidia’s (NVDA) delicate dance in China continues. Amid U.S. export restrictions on its advanced AI chips, the chip giant valued at $3.3 trillion is...', 'polarity': 0.03333333333333335}
# {'date': '2025-05-19', 'source': 'Rock Paper Shotgun', 'title': 'Only press who previewed the RTX 5060 under Nvidia’s test conditions are getting review drivers, reports claim', 'description': 'In classic me fashion, I swanned off for a few days just as another graphics card fracas has spilled out into public view. At the centre this time is the previously unassuming RTX 5060, which you may have noticed is due for launch today yet only has a handful…', 'polarity': -0.05416666666666667}
# {'date': '2025-05-27', 'source': 'Yahoo Entertainment', 'title': 'Buying Nvidia Stock Before May 28 Could Be Your Last Chance to Get This Magnificent Artificial Intelligence (AI) Stock on the Cheap', 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-29', 'source': 'Gizmodo.com', 'title': 'Nvidia’s GeForce Now Made Me Forget All About Wanting a Steam Deck 2', 'description': "Streaming also means your Steam Deck's battery may finally last six hours.", 'polarity': 0.0}
# {'date': '2025-05-13', 'source': 'XDA Developers', 'title': "Nvidia's treatment of the RTX 50 series shows the company doesn't care about gaming anymore", 'description': 'It seems Nvidia has left gamers in the dust.', 'polarity': 0.0}
# {'date': '2025-05-08', 'source': 'Windows Central', 'title': "3 of NVIDIA's biggest red flags I can't ignore for its upcoming RTX 5060 launch", 'description': "NVIDIA's RTX 5060 is expected to launch on May 19. Unfortunately, NVIDIA looks to be limiting review driver access, adding another red flag to the launch.", 'polarity': -0.19999999999999998}
# {'date': '2025-05-23', 'source': 'Windows Central', 'title': "My favorite gaming service is 40% off right now (and no, it's not Xbox Game Pass)", 'description': "NVIDIA GeForce Now has become my favorite gaming service, surpassing even Xbox Game Pass in streaming quality and convenience. Right now, it's a whopping 40% off.", 'polarity': 0.12857142857142856}
# {'date': '2025-05-19', 'source': 'Windows Central', 'title': "DOOM: The Dark Ages PC launch has been dismal, but not because it's a bad game — I'm not surprised if player counts are lower", 'description': "NVIDIA gamers are still in the majority on PC, and they've been sorely let down with DOOM: The Dark Ages. So it's not surprising numbers are low.", 'polarity': -0.1638888888888889}
# {'date': '2025-05-29', 'source': 'Windows Central', 'title': "NVIDIA GeForce NOW launches a native Steam Deck app, unlocking 4K cloud gaming & extended battery life for Valve's handheld", 'description': "NVIDIA GeForce NOW has officially launched a native cloud gaming app for the Steam Deck. It's a great way to expand your options without upgrading hardware.", 'polarity': 0.8}
# {'date': '2025-05-19', 'source': 'Windows Central', 'title': "NVIDIA's RTX 5060 is here, but don't expect to read any real reviews", 'description': "NVIDIA launched its RTX 5060 GPUs for desktops and laptops today, but they come without any real reviews. Here's what's going on behind the scenes.", 'polarity': -0.1}
# {'date': '2025-05-19', 'source': 'Windows Central', 'title': 'The Razer Blade 14 got the AI laptop treatment with less weight, more ports and speakers, and two colors', 'description': 'The Razer Blade 14 (2025) has been announced, bringing a redesign with AMD Ryzen AI, NVIDIA GeForce RTX 50-series, less weight and thickness, and more features.', 'polarity': 0.16666666666666669}
# {'date': '2025-05-20', 'source': 'Windows Central', 'title': "Samsung takes on LG's best gaming TVs — adds NVIDIA G-SYNC support to 2025 flagship", 'description': "Samsung's 2025 OLED TV lineup supports NVIDIA G-SYNC and up to a 165Hz refresh rate when using the company's Motion Xcelerator technology.", 'polarity': 0.0}
# {'date': '2025-05-20', 'source': 'Windows Central', 'title': "NVIDIA's latest driver fixes some big issues with DOOM: The Dark Ages", 'description': 'After a pretty poor launch of DOOM: The Dark Ages for NVIDIA graphics users, the latest driver does at least fix some of the biggest issues.', 'polarity': -0.020000000000000007}
# {'date': '2025-05-27', 'source': 'Windows Central', 'title': "NVIDIA's new bug is affecting RTX 5060 GPUs — here's how to fix black screens on reboot", 'description': "There's a new black screen bug affecting RTX 5060 and RTX 5060 Ti GPUs, but NVIDIA has taken the initiative by explaining and, more importantly, offering a fix.", 'polarity': 0.21742424242424244}
# {'date': '2025-05-21', 'source': 'Rock Paper Shotgun', 'title': 'Nvidia GeForce RTX 5060 review: passable GPU, shame about the drivers', 'description': 'I’d so desperately like to do a graphics card review without the fug of a wider controversy (or cacked-up market conditions), but the RTX 50 series hasn’t been particularly cooperative in that regard, so why should the RTX 5060 be any different? This time, th…', 'polarity': -0.14444444444444446}
# {'date': '2025-05-14', 'source': 'Phandroid - News for Android', 'title': 'Nvidia and MediaTek may debut laptop chip to rival Snapdragon X at Computex', 'description': 'Nvidia and MediaTek might unveil a laptop-friendly chip to rival Snapdragon X at Computex, targeting everyday users with the N1 and N1X.\nThe post Nvidia and MediaTek may debut laptop chip to rival Snapdragon X at Computex appeared first on Phandroid.', 'polarity': 0.024999999999999994}
# {'date': '2025-05-21', 'source': 'Business Insider', 'title': "Elon Musk says he isn't ruling out merging xAI and Tesla", 'description': 'Tesla CEO Elon Musk said "anything is possible" when asked about merging xAI and Tesla, but said there are no plans to do so.', 'polarity': 0.0}
# {'date': '2025-05-30', 'source': 'XDA Developers', 'title': 'PSA: If you have an Nvidia GPU and use Firefox, update your browser ASAP', 'description': 'Nvidia GPUs and Firefox didn’t get along in the last update', 'polarity': 0.0}
# {'date': '2025-05-29', 'source': 'Windows Central', 'title': "NVIDIA's leaked APU could change gaming laptop design forever. Here's why.", 'description': "It's rumored that NVIDIA has been working on a new APU for Windows laptops since 2023, and a new leak provides a look at the design. Here's why it's a big deal for gaming PCs.", 'polarity': 0.0909090909090909}
# {'date': '2025-05-12', 'source': 'Windows Central', 'title': "NVIDIA's new GPU driver adds DOOM: The Dark Ages support and improves DLSS in Microsoft Flight Simulator 2024", 'description': 'DOOM: The Dark Ages launches May 13 in early access, and those with an NVIDIA GPU will need this Game Ready driver to make it look as good as possible.', 'polarity': 0.075}
# {'date': '2025-05-14', 'source': 'Time', 'title': 'Trump is Rewriting How the U.S. Treats AI Chip Exports—and the Stakes Are Enormous', 'description': 'Some national security experts are alarmed that Trump is shipping advanced AI tools to the Middle East.', 'polarity': 0.2}
# {'date': '2025-05-25', 'source': 'Yahoo Entertainment', 'title': 'Nvidia RTX PRO 6000D (B40) Blackwell GPUs reportedly set to supersede banned H20 accelerators in China', 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-27', 'source': 'Yahoo Entertainment', 'title': "Nvidia sees $2.5 billion Q1 revenue loss from Trump's China chip export ban, warns of more", 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-07', 'source': 'Yahoo Entertainment', 'title': 'Prediction: This Artificial Intelligence (AI) Stock Could Be Worth More Than Nvidia by 2030', 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-20', 'source': 'Yahoo Entertainment', 'title': "'Jensanity': Nvidia boss Jensen Huang gets rock star welcome in Taiwan", 'description': 'No description provided', 'polarity': 0.0}
# {'date': '2025-05-13', 'source': 'Windows Central', 'title': "NVIDIA's drivers are causing big problems for DOOM: The Dark Ages, but some fixes are available", 'description': 'DOOM: The Dark Ages is here, but it arrives with a long list of issues. Most are related to PC, with NVIDIA drivers seemingly causing the most chaos. Good news: some fixes are available.', 'polarity': 0.2714285714285714}
# {'date': '2025-05-15', 'source': 'Windows Central', 'title': "Intel could be prepping a new mid-range GPU, giving gamers another reason to skip NVIDIA's RTX 5060", 'description': "Intel's social media team has been teasing us with Arc B770 hints lately, which is great news for value-conscious PC gamers looking for an alternative to NVIDIA and AMD.", 'polarity': 0.1777777777777778}
# {'date': '2025-05-15', 'source': 'Windows Central', 'title': "'Fake' frames? Who cares when a game looks this good — DOOM: The Dark Ages tested with NVIDIA's Multi Frame Gen", 'description': "DOOM: The Dark Ages arrives with native ray tracing and heavy system demands, which is a perfect testing bed for NVIDIA's Multi Frame Gen. Here are the results.", 'polarity': 0.21666666666666667}
# {'date': '2025-05-29', 'source': 'Theregister.com', 'title': 'Nvidia is cozying up to China with Shanghai R&D lab plans, Senators cry', 'description': "Banks and Warren accuse chip maker of habitual 'disregard for US national security and support for autocratic regimes'\nNvidia is reportedly planning to open a new research and development facility in Shanghai, China, drawing sharp criticism from a pair of US …", 'polarity': 0.0037878787878787845}
# {'date': '2025-05-07', 'source': 'Android Police', 'title': 'Nvidia opens the floodgates to its latest Shield TV update; you no longer have to opt in', 'description': "Last month's opt-in Shield TV update has morphed into a full-fledged release for every Shield owner, out now", 'polarity': 0.3}
# {'date': '2025-05-19', 'source': 'Windows Central', 'title': 'DOOM: The Dark Ages gets Path Tracing update in June, bringing better visuals for PC players', 'description': "id Software and Bethesda Softworks' latest shooter is getting a major update in June, bringing promised Path Tracing visuals.", 'polarity': 0.28125}
# {'date': '2025-05-20', 'source': 'Phandroid - News for Android', 'title': 'MediaTek Makes Big Announcements at Computex 2025', 'description': 'MediaTek took to stage to announce new AI updates, including its work on AI, 6G, edge, and cloud computing.\nThe post MediaTek Makes Big Announcements at Computex 2025 appeared first on Phandroid.', 'polarity': 0.12878787878787878}
# {'date': '2025-05-19', 'source': 'XDA Developers', 'title': '$50,000 is up for grabs for aspiring game devs to make a sweet RTX Remix mod', 'description': "I can't wait to see what developers come up with.", 'polarity': 0.0}
# {'date': '2025-05-07', 'source': 'Android Authority', 'title': 'NVIDIA follows up last month’s Shield TV hotfix with an update that won’t break your apps', 'description': "NVIDIA has cleaned up last month's hotfix update with a stable 9.2.1 release that's ready for all its users to install.", 'polarity': 0.1}
# {'date': '2025-05-29', 'source': 'Business Insider', 'title': "The CEO of a top AI startup gave a stark warning about the tech's impact on the labor market", 'description': "A top AI executive is ringing the alarm bell on AI in the workplace, but it's not all bad news.", 'polarity': -0.09999999999999992}
# {'date': '2025-05-19', 'source': 'Theregister.com', 'title': 'Nvidia sets up shop in Taiwan with AI supers and a factory full of ambition', 'description': 'Researchers and TSMC to benefit from expanded infrastructure\nComputex Against a backdrop of mounting tensions between the US and China, with Taiwan typically stuck in the middle, Nvidia is touting two AI supercomputers for the country.…', 'polarity': -0.08333333333333333}

# %% [markdown]
# # Stocks

# %%
# Polygon.io API key
api_key = "XjYt_dkqf8RGZoPqstKOCrTozpC5CtsI"

# %%
# Stock symbol for Nvidia
symbol = "NVDA"

# Date range for the stock data
start_date = "2024-05-05"
end_date = "2024-05-30"

# %%
# API URL to fetch the stock data from Polygon.io
url = f"https://api.polygon.io/v2/aggs/ticker/{symbol}/range/1/day/{start_date}/{end_date}?apiKey={api_key}"

# %%
# Make a request to Polygon.io API
response = requests.get(url)
data = response.json()

# %%
df_stocks = []

# Check if the response contains results
if 'results' in data:
    # Iterate through the data for each day
    for item in data['results']:
        # Get stock data: open, close, high, low values
        timestamp = item['t']  # Timestamp (in milliseconds)
        open_price = item['o']  # Open price
        close_price = item['c']  # Close price
        high_price = item['h']  # High price
        low_price = item['l']  # Low price
        
        # Convert timestamp to a readable date format
        date_str = datetime.utcfromtimestamp(timestamp / 1000).strftime('%Y-%m-%d')

        # Classify the stock movement based on open and close prices
        if close_price > open_price:
            movement_class = 1  # Up
        else:
            movement_class = 0  # Down

        # Prepare the message for Kafka
        message = {
            "date": date_str,
            "symbol": symbol,
            "open": open_price,
            "close": close_price,
            "high": high_price,
            "low": low_price,
            "movement_class": movement_class  # Adding classifier: 1 for up, 0 for down
        }

        df_stocks.append(message)

        print(f"{message}")
else:
    print("No data found or error with the API request")
# Out:
# {'date': '2024-05-06', 'symbol': 'NVDA', 'open': 89.39, 'close': 92.14, 'high': 92.22, 'low': 89.055, 'movement_class': 1}
# {'date': '2024-05-07', 'symbol': 'NVDA', 'open': 91.098, 'close': 90.554, 'high': 91.781, 'low': 89.011, 'movement_class': 0}
# {'date': '2024-05-08', 'symbol': 'NVDA', 'open': 89.4825, 'close': 90.412, 'high': 91.194, 'low': 89.42, 'movement_class': 1}
# {'date': '2024-05-09', 'symbol': 'NVDA', 'open': 90.529, 'close': 88.747, 'high': 91.072, 'low': 88.231, 'movement_class': 0}
# {'date': '2024-05-10', 'symbol': 'NVDA', 'open': 90.3045, 'close': 89.878, 'high': 91.401, 'low': 89.227, 'movement_class': 0}
# {'date': '2024-05-13', 'symbol': 'NVDA', 'open': 90.478, 'close': 90.399, 'high': 90.998, 'low': 88.529, 'movement_class': 0}
# {'date': '2024-05-14', 'symbol': 'NVDA', 'open': 89.599, 'close': 91.356, 'high': 91.651, 'low': 88.934, 'movement_class': 1}
# {'date': '2024-05-15', 'symbol': 'NVDA', 'open': 92.472, 'close': 94.63, 'high': 94.862, 'low': 91.599, 'movement_class': 1}
# {'date': '2024-05-16', 'symbol': 'NVDA', 'open': 94.91, 'close': 94.359, 'high': 95.819, 'low': 94.103, 'movement_class': 0}
# {'date': '2024-05-17', 'symbol': 'NVDA', 'open': 94.369, 'close': 92.479, 'high': 94.74, 'low': 91.806, 'movement_class': 0}
# {'date': '2024-05-20', 'symbol': 'NVDA', 'open': 93.75, 'close': 94.78, 'high': 95.2, 'low': 93.44, 'movement_class': 1}
# {'date': '2024-05-21', 'symbol': 'NVDA', 'open': 93.599, 'close': 95.386, 'high': 95.4, 'low': 93.18, 'movement_class': 1}
# {'date': '2024-05-22', 'symbol': 'NVDA', 'open': 95.459, 'close': 94.95, 'high': 96.02, 'low': 93.249, 'movement_class': 0}
# {'date': '2024-05-23', 'symbol': 'NVDA', 'open': 102.028, 'close': 103.799, 'high': 106.32, 'low': 101.52, 'movement_class': 1}
# {'date': '2024-05-24', 'symbol': 'NVDA', 'open': 104.449, 'close': 106.469, 'high': 106.475, 'low': 103, 'movement_class': 1}
# {'date': '2024-05-28', 'symbol': 'NVDA', 'open': 110.244, 'close': 113.901, 'high': 114.939, 'low': 109.883, 'movement_class': 1}
# {'date': '2024-05-29', 'symbol': 'NVDA', 'open': 113.05, 'close': 114.825, 'high': 115.492, 'low': 110.901, 'movement_class': 1}
# {'date': '2024-05-30', 'symbol': 'NVDA', 'open': 114.65, 'close': 110.5, 'high': 115.8192, 'low': 109.663, 'movement_class': 0}

# %% [markdown]
# # Visualizations

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Convert results to DataFrame
df_news = pd.DataFrame(df_news)

# Drop the rows with '[Removed]'
df_news = df_news[df_news['source'] != '[Removed]']

# Display the DataFrame
df_news.head()
# Out:
#          date     source                                              title  \
# 0  2025-05-14  The Verge  Nvidia’s flattery of Trump wins reversal of AI...
# 1  2025-05-08  The Verge  Lenovo’s flagship gaming laptop has a 2D / 3D ...
# 2  2025-05-14  The Verge  Switch 2 spec breakdown digs into its processo...
# 3  2025-05-15      Wired      The Middle East Has Entered the AI Group Chat
# 4  2025-05-29  The Verge  Tested: Nvidia’s GeForce Now just breathed new...
#
#                                          description  polarity
# 0  Nvidia’s efforts to suck up to the Trump admin... -0.155556
# 1  Lenovo is announcing a new 10th-generation Leg...  0.136364
# 2  Nintendo’s Switch 2 specs page is light on det...  0.134091
# 3  The UAE and Saudi Arabia are investing billion...  0.000000
# 4  I don't want gaming to become another streamin...  0.178571

# %%
# Number of rows
df_news.shape[0]
# Out:
# 98

# %%
# Generate a histogram for sentiment polarity
plt.figure(figsize=(8, 6))
sns.histplot(df_news['polarity'], bins=10, kde=True, color='blue')

# Customize the plot
plt.title('Distribution of Sentiment Polarity for Articles', fontsize=16)
plt.xlabel('Sentiment Polarity', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df_stocks = pd.DataFrame(df_stocks)

# %%
df_stocks['date'] = pd.to_datetime(df_stocks['date'])

# %%
# Plot stock prices
plt.figure(figsize=(12, 6))
plt.plot(df_stocks['date'], df_stocks['open'], label='Open Price', marker='o')
plt.plot(df_stocks['date'], df_stocks['close'], label='Close Price', marker='o')
plt.fill_between(df_stocks['date'], df_stocks['low'], df_stocks['high'], color='lightblue', alpha=0.3, label='High-Low Range')
plt.title("Nvidia Stock Prices")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.show()

# %%
print(df_news.shape)
print(df_stocks.shape)
# Out:
# (98, 5)
# (18, 7)

# %%
df_stocks.to_csv("output.csv", index=False)

# %%
aggregated_polarity = df_news.groupby("date")["polarity"].mean().reset_index()

# Rename columns for clarity
aggregated_polarity.columns = ["date", "mean_polarity"]

print(aggregated_polarity)
# Out:
#           date  mean_polarity
# 0   2025-05-05       0.250000
# 1   2025-05-06       0.208333
# 2   2025-05-07       0.207110
# 3   2025-05-08      -0.053409
# 4   2025-05-09       0.068254
# 5   2025-05-10       0.045455
# 6   2025-05-11       0.500000
# 7   2025-05-12       0.075000
# 8   2025-05-13       0.066104
# 9   2025-05-14       0.055862
# 10  2025-05-15      -0.029762
# 11  2025-05-16       0.068182
# 12  2025-05-17      -0.100000
# 13  2025-05-18       0.233333
# 14  2025-05-19       0.093703
# 15  2025-05-20       0.121758
# 16  2025-05-21       0.381111
# 17  2025-05-22       0.383929
# 18  2025-05-23       0.104286
# 19  2025-05-25       0.000000
# 20  2025-05-27       0.059596
# 21  2025-05-28      -0.066667
# 22  2025-05-29       0.090633
# 23  2025-05-30       0.016667

# %%
# Merge the DataFrames on the 'date' column

df_merged = pd.concat([aggregated_polarity, df_stocks], axis=1)

# %%
df_merged = df_merged.dropna(subset=["movement_class"])

# %%
df_merged.shape
# Out:
# (18, 9)

# %%
df_merged.head(7)
# Out:
#          date  mean_polarity       date symbol     open   close    high  \
# 0  2025-05-05       0.250000 2024-05-06   NVDA  89.3900  92.140  92.220
# 1  2025-05-06       0.208333 2024-05-07   NVDA  91.0980  90.554  91.781
# 2  2025-05-07       0.207110 2024-05-08   NVDA  89.4825  90.412  91.194
# 3  2025-05-08      -0.053409 2024-05-09   NVDA  90.5290  88.747  91.072
# 4  2025-05-09       0.068254 2024-05-10   NVDA  90.3045  89.878  91.401
# 5  2025-05-10       0.045455 2024-05-13   NVDA  90.4780  90.399  90.998
# 6  2025-05-11       0.500000 2024-05-14   NVDA  89.5990  91.356  91.651
#
#       low  movement_class
# 0  89.055             1.0
# 1  89.011             0.0
# 2  89.420             1.0
# 3  88.231             0.0
# 4  89.227             0.0
# 5  88.529             0.0
# 6  88.934             1.0
